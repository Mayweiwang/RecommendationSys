# %% [markdown]
# ## This is my first Ipython Notebook Test
# I have been amazyed by how well the RStudio can show the `R` codes and results in both a scientific and readable way. I thought there is no such easy way to share my learning experience of python. But, I was wrong. So, today I will do a simple demo on how I write python and how it is shown directly with Markdown. The official link for ipython notebook is given as http://ipython.org/ipython-doc/1/interactive/notebook.html
#
# I am a Mac system user, and I will list all the steps I have done:
# <ul>
# <li> to open my terminal and type in "ipython notebook --pylab inline".
# This line will launch the webbrowser and pull up a tab for me to write a notebook.</li>
# <li> to install the Python data analysis library "pandas" </li>
# <li> to download the dataset from the link http://grouplens.org/datasets/movielens/ </li>
# <li> to do data analysis using database-related clauses </li>
# <li> to save the notebook into .ipynb file </li>
# <li> to export the .ipynb file </li>
# </ul>

# %% [markdown]
# ### Let's start the journey now!
# #### Play around with some features of python

# %%
import os
from IPython.core.display import Image 
#Image('http://www.google.fr/images/srpr/logo3w.png')
#os.listdir("./")
Image(filename='./ipython1.png')

# %%
Image(filename='./logo.png')

# %% [markdown]
# We can also use some common shell commands, e.g., ls, pwd

# %%
ls
# Out:
# applied-data-science/    ml1mtable.py             recommendations.pyc
# graphlabdemo/            ml1mtable.pyc            recsystable.py
# iPythontest1.ipynb       party_rcs.ipynb          recsystable.pyc
# ipython1.png             pydelicious/             remote.py
# logo.png                 recipe/                  test.ipynb
# matplotlibExample.ipynb  recommendations.ipynb
# ml-1m/                   recommendations.py

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# ### Install python data analysis library "pandas"

# %% [markdown]
# This line doesn't work in the first try, because I haven't installed pandas.
# <ul>
# <li> sudo pip2.7 install pandas</li>
# </ul>

# %% [markdown]
# ### The MovieLens dataset: loading and first look
# Loading of the MovieLens dataset here is based on the intro chapter of "Python for Data Analysis".
# The MovieLens data is spread across three files. Using the pd.read_table method we load each file:

# %%
import pandas as pd
# user table
unames = ['user_id', 'gender', 'age', 'occupation', 'zip']
users = pd.read_table('./ml-1m/users.dat',
                     sep='::',header=None, names=unames,engine='python')
# user-movie-rating table
rnames = ['user_id', 'movie_id', 'rating', 'timestamp']
ratings = pd.read_table('./ml-1m/ratings.dat',
                        sep='::', header=None, names=rnames,engine='python')
# movie table
mnames = ['movie_id', 'title', 'genres']
movies = pd.read_table('./ml-1m/movies.dat',
                       sep='::', header=None, names=mnames,engine='python')

# show how one of them looks
ratings.head(1)
# show how one of them looks
#users[:6]
# Out:
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760

# %%
users.head(1)
# Out:
#    user_id gender  age  occupation    zip
# 0        1      F    1          10  48067

# %%
ratings.shape
movies.shape
movies.head(3)
# Out:
#    movie_id                    title                        genres
# 0         1         Toy Story (1995)   Animation|Children's|Comedy
# 1         2           Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3  Grumpier Old Men (1995)                Comedy|Romance

# %%
index = movies.index[movies['movie_id']== 588]
movies.ix[index]
# Out:
#      movie_id           title                               genres
# 584       588  Aladdin (1992)  Animation|Children's|Comedy|Musical

# %%
# Out:
#       movie_id                 title                       genres
# 2286      2355  Bug's Life, A (1998)  Animation|Children's|Comedy

# %%
print users.ix[0].loc['age']
# Out:
# 1

# %%
print users.shape
# Out:
# (6040, 5)

# %%
print users[[1]].head(6) # get a column of the table
# Out:
#   gender
# 0      F
# 1      M
# 2      M
# 3      M
# 4      M
# 5      F

# %%
usernames = ['seq','ip','email','weixin_nickname','weixin_sex','weixin_addr','score','start','finish','status']
userswei = pd.read_table('./ml-1m/All_Data_Original.csv',
                     sep=',',header=None, names=unames,engine='python')
#userswei[:6]

# %%
movies[:5]
# Out:
#    movie_id                               title                        genres
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# #### Using 'pd.merge', we get all into one big DataFrame.

# %%
# pd is pandas package for database operation
userMovieRate = pd.merge(pd.merge(ratings, users), movies) # merge 3 tables together
userMovieRate
# Out:
#          user_id  movie_id  rating   timestamp gender  age  occupation    zip  \
# 0              1      1193       5   978300760      F    1          10  48067
# 1              2      1193       5   978298413      M   56          16  70072
# 2             12      1193       4   978220179      M   25          12  32793
# 3             15      1193       4   978199279      M   25           7  22903
# 4             17      1193       5   978158471      M   50           1  95350
# 5             18      1193       4   978156168      F   18           3  95825
# 6             19      1193       5   982730936      M    1          10  48073
# 7             24      1193       5   978136709      F   25           7  10023
# 8             28      1193       3   978125194      F   25           1  14607
# 9             33      1193       5   978557765      M   45           3  55421
# 10            39      1193       5   978043535      M   18           4  61820
# ...

# %% [markdown]
# If I want to check the second record in the table, I can

# %%
userMovieRate.ix[1]
# Out:
# user_id                                            2
# movie_id                                        1193
# rating                                             5
# timestamp                                  978298413
# gender                                             M
# age                                               56
# occupation                                        16
# zip                                            70072
# title         One Flew Over the Cuckoo's Nest (1975)
# genres                                         Drama
# Name: 1, dtype: object

# %%
#help(movielens)

# %% [markdown]
# ## Collaborative filtering: generalizations of the aggregation function
# ### Group by
# <ul>
# <li> split data in an object according to a given key;</li>
# <li> apply a function to each subset;</li>
# <li> apply a function to each subset;</li>
# </ul>
#
# ## To get mean movie "ratings" for each "film" grouped by "gender", we can use the "**pivot_table**" method:

# %%
mean_ratings = userMovieRate.pivot_table('rating', index='title', columns='gender', aggfunc='mean')
#mean_ratings = userMovieRate.pivot_table('rating', index='user_id', columns='title', aggfunc='mean')
mean_ratings[:5]
mean_ratings.head(5)
#mean_ratings[[1]]
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 121
# gender                                F         M
# title
# $1,000,000 Duck (1971)         3.375000  2.761905
# 'Night Mother (1986)           3.388889  3.352941
# 'Til There Was You (1997)      2.675676  2.733333
# 'burbs, The (1989)             2.793478  2.962085
# ...And Justice for All (1979)  3.828571  3.689024

# %%
mean_ratings.hist()
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x156c5ed90>,
#         <matplotlib.axes.AxesSubplot object at 0x155bf6e10>]], dtype=object)

# %% [markdown]
# ## Now let's filter down to movies that received at least 250 ratings (a completely arbitrary number);
#
# To do this, I group the data by title and use size() to get a Series of group sizes for each title:

# %%
ratings_by_title = userMovieRate.groupby('title')
#ratings_by_title.head(5)
# Out:
#          user_id  movie_id  rating   timestamp gender  age  occupation    zip  \
# 0              1      1193       5   978300760      F    1          10  48067
# 1              2      1193       5   978298413      M   56          16  70072
# 2             12      1193       4   978220179      M   25          12  32793
# 3             15      1193       4   978199279      M   25           7  22903
# 4             17      1193       5   978158471      M   50           1  95350
# 1725           1       661       3   978302109      F    1          10  48067
# 1726          23       661       2   978460739      M   35           0  90049
# 1727          49       661       3   977972750      M   18          12  77084
# 1728          53       661       5   977979726      M   25           0  96931
# 1729          57       661       4   977935511      M   18          19  30350
# 2250           1       914       3   978301968      F    1          10  48067
# ...

# %%
ratings_by_title = userMovieRate.groupby('title').size()
ratings_by_title.head(5)
# Out:
# title
# $1,000,000 Duck (1971)            37
# 'Night Mother (1986)              70
# 'Til There Was You (1997)         52
# 'burbs, The (1989)               303
# ...And Justice for All (1979)    199
# dtype: int64

# %% [markdown]
# ### Let's see, for Series type '.index' is a function

# %%
#ratings_by_title.index[:3]
type(ratings_by_title.index[:3])
# Out:
# pandas.core.index.Index

# %%
index=[ratings_by_title >500]
# dir(index)  # cool trick to check what methods does the object have
print index
# Out:
# [title
# $1,000,000 Duck (1971)                 False
# 'Night Mother (1986)                   False
# 'Til There Was You (1997)              False
# 'burbs, The (1989)                     False
# ...And Justice for All (1979)          False
# 1-900 (1994)                           False
# 10 Things I Hate About You (1999)       True
# 101 Dalmatians (1961)                   True
# 101 Dalmatians (1996)                  False
# 12 Angry Men (1957)                     True
# 13th Warrior, The (1999)                True
# 187 (1997)                             False
# 2 Days in the Valley (1996)            False
# 20 Dates (1998)                        False
# 20,000 Leagues Under the Sea (1954)     True
# ...
# You've Got Mail (1998)                         True
# Young Doctors in Love (1982)                  False
# Young Frankenstein (1974)                      True
# Young Guns (1988)                              True
# Young Guns II (1990)                          False
# ...

# %%
active_titles = ratings_by_title.index[ratings_by_title >= 250] # Series.ix return a Series; Series.index return an index
len(active_titles)
type(active_titles)
# Out:
# pandas.core.index.Index

# %% [markdown]
# ### The index of titles receiving at least 250 ratings can then be used to select rows from mean_ratings above:

# %%
mean_ratings = mean_ratings.ix[active_titles]
mean_ratings
# Out:
# gender                                                                     F  \
# title
# 'burbs, The (1989)                                                  2.793478
# 10 Things I Hate About You (1999)                                   3.646552
# 101 Dalmatians (1961)                                               3.791444
# 101 Dalmatians (1996)                                               3.240000
# 12 Angry Men (1957)                                                 4.184397
# 13th Warrior, The (1999)                                            3.112000
# 2 Days in the Valley (1996)                                         3.488889
# 20,000 Leagues Under the Sea (1954)                                 3.670103
# 2001: A Space Odyssey (1968)                                        3.825581
# 2010 (1984)                                                         3.446809
# 28 Days (2000)                                                      3.209424
# ...

# %% [markdown]
# ### To see the top films among female viewers, we can sort by the "F" column in descending order:

# %%
top_female_ratings = mean_ratings.sort_index(by='F', ascending=False)
top_female_ratings[:10]
# Out:
# gender                                                         F         M
# title
# Close Shave, A (1995)                                   4.644444  4.473795
# Wrong Trousers, The (1993)                              4.588235  4.478261
# Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)           4.572650  4.464589
# Wallace & Gromit: The Best of Aardman Animation (1996)  4.563107  4.385075
# Schindler's List (1993)                                 4.562602  4.491415
# Shawshank Redemption, The (1994)                        4.539075  4.560625
# Grand Day Out, A (1992)                                 4.537879  4.293255
# To Kill a Mockingbird (1962)                            4.536667  4.372611
# Creature Comforts (1990)                                4.513889  4.272277
# Usual Suspects, The (1995)                              4.513317  4.518248

# %% [markdown]
# ### Measuring rating disagreement
# Suppose you wanted to find the movies that are most divisive between male and female viewers.
#
# One way is to add a column to mean_ratings containing the difference in means, then sort by that:

# %%
mean_ratings['diff'] = mean_ratings['M'] - mean_ratings['F']
sorted_by_diff = mean_ratings.sort_index(by='diff')
sorted_by_diff[:15]
type(mean_ratings)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Reversing the order of the rows and again slicing off the top 15 rows, we get the movies preferred by men that women didn’t rate as highly:

# %%
sorted_by_diff[::-1][:15]
# Out:
# gender                                         F         M      diff
# title
# Good, The Bad and The Ugly, The (1966)  3.494949  4.221300  0.726351
# Kentucky Fried Movie, The (1977)        2.878788  3.555147  0.676359
# Dumb & Dumber (1994)                    2.697987  3.336595  0.638608
# Longest Day, The (1962)                 3.411765  4.031447  0.619682
# Cable Guy, The (1996)                   2.250000  2.863787  0.613787
# Evil Dead II (Dead By Dawn) (1987)      3.297297  3.909283  0.611985
# Hidden, The (1987)                      3.137931  3.745098  0.607167
# Rocky III (1982)                        2.361702  2.943503  0.581801
# Caddyshack (1980)                       3.396135  3.969737  0.573602
# For a Few Dollars More (1965)           3.409091  3.953795  0.544704
# Porky's (1981)                          2.296875  2.836364  0.539489
# Animal House (1978)                     3.628906  4.167192  0.538286
# ...

# %% [markdown]
# ## Suppose instead you wanted the movies that elicited the most disagreement among viewers, independent of gender. Disagreement can be measured by the variance or standard deviation of the ratings:

# %%
# Standard deviation of rating grouped by title
rating_std_by_title = userMovieRate.groupby('title')['rating'].std()
type(rating_std_by_title)
# Out:
# pandas.core.series.Series

# %%
# Filter down to active_titles
rating_std_by_title = rating_std_by_title.ix[active_titles]  # Series.ix[index] returns a Series
rating_std_by_title
# Out:
# title
# 'burbs, The (1989)                     1.107760
# 10 Things I Hate About You (1999)      0.989815
# 101 Dalmatians (1961)                  0.982103
# 101 Dalmatians (1996)                  1.098717
# 12 Angry Men (1957)                    0.812731
# 13th Warrior, The (1999)               1.140421
# 2 Days in the Valley (1996)            0.921592
# 20,000 Leagues Under the Sea (1954)    0.869685
# 2001: A Space Odyssey (1968)           1.042504
# 2010 (1984)                            0.946618
# 28 Days (2000)                         0.920278
# 39 Steps, The (1935)                   0.853501
# 54 (1998)                              1.035481
# 7th Voyage of Sinbad, The (1958)       0.931531
# 8MM (1999)                             1.113432
# ...
# Working Girl (1988)                      0.879409
# World Is Not Enough, The (1999)          0.972892
# Wrong Trousers, The (1993)               0.708666
# Wyatt Earp (1994)                        0.922257
# ...

# %%
# Order Series by value in descending order 
rating_std_by_title.order(ascending=False)[:10]
# Out:
# title
# Dumb & Dumber (1994)                     1.321333
# Blair Witch Project, The (1999)          1.316368
# Natural Born Killers (1994)              1.307198
# Tank Girl (1995)                         1.277695
# Rocky Horror Picture Show, The (1975)    1.260177
# Eyes Wide Shut (1999)                    1.259624
# Evita (1996)                             1.253631
# Billy Madison (1995)                     1.249970
# Fear and Loathing in Las Vegas (1998)    1.246408
# Bicentennial Man (1999)                  1.245533
# Name: rating, dtype: float64

# %% [markdown]
# ## Evaluation
# Before we attempt to express the basic equations for content-based or collaborative filtering we need a basic mechanism to evaluate the performance of our engine.
#
# Evaluation: split ratings into train and test sets
# This subsection will generate training and testing sets for evaluation. You do not need to understand every single line of code, just the general gist:
#
# <li>take a smaller sample from the full 1M dataset for speed reasons;</li>
# <li>make sure that we have at least 2 ratings per user in that subset;</li>
# <li>split the result into training and testing sets.</li>

# %%
help(np.random.choice)
# Out:
# Help on built-in function choice:
#
# choice(...)
#     choice(a, size=None, replace=True, p=None)
#
#     Generates a random sample from a given 1-D array
#
#             .. versionadded:: 1.7.0
#
#     Parameters
#     -----------
#     a : 1-D array-like or int
#         If an ndarray, a random sample is generated from its elements.
#         If an int, the random sample is generated as if a was np.arange(n)
#     size : int or tuple of ints, optional
#         Output shape. Default is None, in which case a single value is
#         returned.
#     replace : boolean, optional
#         Whether the sample is with or without replacement
#     p : 1-D array-like, optional
#         The probabilities associated with each entry in a.
#         If not given the sample assumes a uniform distribtion over all
#         entries in a.
#
#     Returns
#     --------
#     samples : 1-D ndarray, shape (size,)
#         The generated random samples
#
#     Raises
#     -------
#     ValueError
# ...

# %% [markdown]
# ### Save the notebook in a file "iPythontest1.ipynb"

# %% [markdown]
# ### Export the file .ipynb into a html for this blog

# %% [markdown]
# <ul>
# <li> to install "pandoc" first from the link http://www.texts.io/support/0003/.
# "pandoc"is a universal document text converter. </li>
# <li> to go to the directory with my .ipynb file </li>
# <li> to run the script: ipython nbconvert --template basic iPythontest1.ipynb.
# More formats can be found in http://ipython.org/ipython-doc/3/notebook/nbconvert.html </li>
# </ul>

# %%
import numpy as np
UMRtest = userMovieRate.ix[np.random.choice(userMovieRate.index, size=10000, replace=False)]
print UMRtest.shape
#print movielens.user_id.nunique()
#print movielens.movie_id.nunique()
print UMRtest.columns
# Out:
# (10000, 10)
# Index([u'user_id', u'movie_id', u'rating', u'timestamp', u'gender', u'age', u'occupation', u'zip', u'title', u'genres'], dtype='object')

# %%
userid = UMRtest.user_id

# %%
plot(userid[40:100])

# %%
ratings_by_user = UMRtest.groupby('user_id').size()
index2 = ratings_by_user > 1
#print index2
#active_users = ratings_by_user.index[index2]
len(ratings_by_user.index[index2])
# Out:
# 2185

# %%
userid = UMRtest.user_id

# %%
user_ids_larger_1 = pd.value_counts(userid, sort=False) > 1
print pd.value_counts(userid, sort=False)
len(user_ids_larger_1)
# Out:
# 2049    1
# 8       3
# 4114    1
# 24      1
# 2073    7
# 4122    3
# 2081    1
# 4130    3
# 4138    1
# 48      7
# 2097    2
# 2105    6
# 4154    1
# 64      1
# 4162    1
# ...
# 1983    7
# 1991    1
# 1999    1
# 4054    8
# 2007    1
# 4062    3
# 2015    9
# 4070    1
# 2023    3
# 4078    1
# 2031    1
# 4086    1
# 2039    1
# 4094    4
# 2047    3
# Length: 3706, dtype: int64
# 3706

# %%
print len(userid), len(user_ids_larger_1)
userid.index[1]
# Out:
# 10000 3706
# 635222

# %%
temp = user_ids_larger_1[userid]
print temp.shape, 

user_ids_larger_1
# Out:
# (10000,)
# 2049    False
# 8        True
# 4114    False
# 24      False
# 2073     True
# 4122     True
# 2081    False
# 4130     True
# 4138    False
# 48       True
# 2097     True
# 2105     True
# 4154    False
# 64      False
# 4162    False
# ...
# 1983     True
# 1991    False
# 1999    False
# 4054     True
# 2007    False
# 4062     True
# 2015     True
# 4070    False
# 2023     True
# 4078    False
# 2031    False
# 4086    False
# 2039    False
# 4094     True
# 2047     True
# Length: 3706, dtype: bool

# %%
# userid.value_counts() is equivalent to pd.value_counts(userid,sort=True)

# %%
movielens = UMRtest[user_ids_larger_1[userid].values]
print movielens.shape
np.all(userid.value_counts() > 1)
# Out:
# (8479, 10)
# False

# %%
import numpy as np
def assign_to_set(df):
    sampled_ids = np.random.choice(df.index,
                                   size=np.int64(np.ceil(df.index.size * 0.2)),
                                   replace=False)
    df.ix[sampled_ids, 'for_testing'] = True
    return df

movielens['for_testing'] = False
grouped = movielens.groupby('user_id', group_keys=False).apply(assign_to_set)
movielens_train = movielens[grouped.for_testing == False]
movielens_test = movielens[grouped.for_testing == True]
print movielens_train.shape
print movielens_test.shape
print movielens_train.index & movielens_test.index
# Out:
# (5824, 11)
# (2655, 11)
# Int64Index([], dtype='int64')
# -c:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
movielens_train.to_csv('./ml-1m/movielens_train.csv')
movielens_test.to_csv('./ml-1m/movielens_test.csv')

# %%
def compute_rmse(y_pred, y_true):
    """ Compute Root Mean Squared Error. """
    return np.sqrt(np.mean(np.power(y_pred - y_true, 2)))

# %%
def evaluate(estimate_f):
    """ RMSE-based predictive performance evaluation with pandas. """
    ids_to_estimate = zip(movielens_test.user_id, movielens_test.movie_id)
    estimated = np.array([estimate_f(u,i) for (u,i) in ids_to_estimate])
    real = movielens_test.rating.values
    return compute_rmse(estimated, real)

# %% [markdown]
# ## Content-based filtering using mean ratings
# With this table-like representation of the ratings data, a basic content-based filter becomes a one-liner function.

# %%
def estimate1(user_id, item_id):
    """ Simple content-filtering based on mean ratings. """
    return movielens_train.ix[movielens_train.user_id == user_id, 'rating'].mean()

print 'RMSE for estimate1: %s' % evaluate(estimate1)
# Out:
# RMSE for estimate1: 1.279746336

# %%
def estimate2(user_id, movie_id):
    """ Simple collaborative filter based on mean ratings. """
    ratings_by_others = movielens_train[movielens_train.movie_id == movie_id]
    if ratings_by_others.empty: return 3.0
    return ratings_by_others.rating.mean()

print 'RMSE for estimate2: %s' % evaluate(estimate2)
# Out:
# RMSE for estimate2: 1.14556385922

# %% [markdown]
# ## Pivoting
# Let's start with a simple pivoting example that does not involve any aggregation. We can extract a ratings matrix as follows:

# %%
# transform the ratings frame into a ratings matrix
ratings_mtx_df = movielens_train.pivot_table(values='rating',
                                             rows='user_id',
                                             columns='movie_id')
ratings_mtx_df
# Out:
# movie_id  1     2     4     5     6     7     9     10    11    12    ...   \
# user_id                                                               ...
# 4          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 9          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 10         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 15         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 17         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 19         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 23         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 25         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 26         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 28         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...

# %%
# with an integer axis index only label-based indexing is possible
ratings_mtx_df.ix[ratings_mtx_df.index[-15:],ratings_mtx_df.columns[:15]]
# Out:
# movie_id  1   2   4   5   6   7   9   10  11  12  13  14  15  16  17
# user_id
# 6007     NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 6009     NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 6014     NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 6015     NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 6016     NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 6018     NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 6019     NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 6021     NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 6023     NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 6025     NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 6030     NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 6035     NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# ...

# %% [markdown]
# ## Collaborative-based filtering using custom sim functions
# Pearson correlation

# %%
import numpy as np; import pandas as pd; from pandas import Series, DataFrame
rating = pd.read_csv('./ml-1m/movie_rating.csv')
rp = rating.pivot_table(cols=['critic'],rows=['title'],values='rating')
rp
# Out:
# /Library/Python/2.7/site-packages/pandas/util/decorators.py:81: FutureWarning: the 'cols' keyword is deprecated, use 'columns' instead
#   warnings.warn(msg, FutureWarning)
# /Library/Python/2.7/site-packages/pandas/util/decorators.py:81: FutureWarning: the 'rows' keyword is deprecated, use 'index' instead
#   warnings.warn(msg, FutureWarning)
# critic              Claudia Puig  Gene Seymour  Jack Matthews  Lisa Rose  \
# title
# Just My Luck                 3.0           1.5            NaN        3.0
# Lady in the Water            NaN           3.0            3.0        2.5
# Snakes on a Plane            3.5           3.5            4.0        3.5
# Superman Returns             4.0           5.0            5.0        3.5
# The Night Listener           4.5           3.0            3.0        3.0
# You Me and Dupree            2.5           3.5            3.5        2.5
#
# critic              Mick LaSalle  Toby
# title
# Just My Luck                   2   NaN
# ...

# %%
import urllib

# %%
response = urllib.urlopen('http://nsl.cs.unb.ca/NSL-KDD/KDDTrain+.txt')
print response.info()
# Out:
# Date: Thu, 26 Mar 2015 17:03:46 GMT
# Server: Apache/2.2.11 (Ubuntu) DAV/2 SVN/1.5.4 PHP/5.2.6-3ubuntu4.6 with Suhosin-Patch proxy_html/3.0.1
# Last-Modified: Wed, 21 Oct 2009 14:27:59 GMT
# ETag: "734574-1239630-47672c91839c0"
# Accept-Ranges: bytes
# Content-Length: 19109424
# Vary: Accept-Encoding
# Connection: close
# Content-Type: text/plain

# %%
html = response.read()
f = open('KDDtrain.txt', 'wb')
f.write(html)
f.close()
response.close()
